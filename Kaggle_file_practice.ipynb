# %%
import json
import pandas as pd
import numpy as np

# %%
# 6 Create the path to your file directory and variables for the three files. 
file_dir = './Resources'
# Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# %%
# Convert to DataFrame
kaggle_file_df = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings_file_df = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
# First five rows
kaggle_file_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Five random rows
kaggle_file_df.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 12747  False                   NaN         0
# 24411  False                   NaN         0
# 20378  False                   NaN         0
# 37732  False                   NaN         0
# 3861   False                   NaN  82000000
#
#                                                   genres  \
# 12747  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# 24411  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 20378  [{'id': 18, 'name': 'Drama'}, {'id': 99, 'name...
# 37732                      [{'id': 18, 'name': 'Drama'}]
# 3861            [{'id': 878, 'name': 'Science Fiction'}]
#
#                                homepage      id    imdb_id original_language  \
# 12747                               NaN   10842  tt0492784                ja
# 24411                               NaN   35017  tt0050213                en
# 20378  http://www.peloterothemovie.com/  114562  tt1885335                es
# 37732   http://www.thetaiwanoyster.com/  132540  tt2115420                en
# 3861                                NaN    8452  tt0216216                en
#
#           original_title                                           overview  \
# 12747            奇妙なサーカス  The erotic novelist Taeko is writing a morbid ...
# 24411  The Brothers Rico  The Rico brothers are mobsters in the employ o...
# 20378           Pelotero  Two top baseball prospects in the Dominican Re...
# 37732  The Taiwan Oyster  Taiwan in the year 2000, only thirteen years a...
# 3861         The 6th Day  Futuristic action about a man who meets a clon...
#
#        ... release_date     revenue runtime  \
# 12747  ...   2005-12-24         0.0   108.0
# 24411  ...   1957-09-01         0.0    92.0
# 20378  ...   2012-07-13     44689.0    77.0
# 37732  ...   2012-03-10         0.0   108.0
# 3861   ...   2000-11-17  96085477.0   123.0
#
#                                         spoken_languages    status  \
# 12747               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 24411  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20378  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 37732                                                 []  Released
# 3861            [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline              title  \
# 12747                                            NaN     Strange Circus
# 24411  Three hunted men and their desperate women...  The Brothers Rico
# 20378  The Dominican Republic's Most Valuable Export         Ballplayer
# 37732                                            NaN  The Taiwan Oyster
# 3861                   Are You Who You Think You Are        The 6th Day
#
#        video vote_average vote_count
# 12747  False          7.1       47.0
# 24411  False          5.7        9.0
# 20378  False          5.9        6.0
# 37732  False          6.8        2.0
# 3861   False          5.7      603.0
#
# [5 rows x 24 columns]

# %%
ratings_file_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556
